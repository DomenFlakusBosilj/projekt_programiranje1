# %% [markdown]
# # Projekt programiranje
# #### Domen Flakus Bosilj
#
# Kr neko besedilo

# %%
import pandas as pd

nepremicnine = pd.read_csv('podatki/nepremicnine11.csv')

pd.options.display.max_rows = 200

# %%
list(nepremicnine["zemljisce"])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
nepremicnine.dtypes
# Out:
# ime           object
# posred        object
# vrsta         object
# tip           object
# leto           int64
# zemljisce    float64
# velikost     float64
# cena         float64
# agencija      object
# dtype: object

# %%
nepremicnine[(nepremicnine.vrsta == 'Stanovanje') | (nepremicnine.vrsta == 'Hiša')]
# Out:
#                                                     ime   posred       vrsta  \
# 0                                            BRESTANICA  Prodaja        Hiša
# 2                                                 CELJE  Prodaja        Hiša
# 3                                       CELJE, OSTROŽNO  Prodaja        Hiša
# 4                                               ČEPOVAN  Prodaja        Hiša
# 5     ČRNA VAS, 5 MIN OD OBVOZNICE - DVOSTANOVANJSKA...  Prodaja        Hiša
# ...                                                 ...      ...         ...
# 8246                             ŽUŽEMBERK, GRAJSKI TRG  Prodaja  Stanovanje
# 8248                          ŽUŽEMBERK, VELIKI LIPOVEC  Prodaja        Hiša
# 8249                          ŽUŽEMBERK, VELIKI LIPOVEC  Prodaja        Hiša
# 8250                                               ŽVAB  Prodaja        Hiša
# 8251                                             ŽVIRČE  Prodaja        Hiša
#
# ...

# %%
nepremicnine[nepremicnine.cena < 500000]
# Out:
#                                                     ime   posred   vrsta  \
# 0                                            BRESTANICA  Prodaja    Hiša
# 2                                                 CELJE  Prodaja    Hiša
# 3                                       CELJE, OSTROŽNO  Prodaja    Hiša
# 4                                               ČEPOVAN  Prodaja    Hiša
# 5     ČRNA VAS, 5 MIN OD OBVOZNICE - DVOSTANOVANJSKA...  Prodaja    Hiša
# ...                                                 ...      ...     ...
# 8247                                   ŽUŽEMBERK, LISEC  Prodaja  Vikend
# 8248                          ŽUŽEMBERK, VELIKI LIPOVEC  Prodaja    Hiša
# 8249                          ŽUŽEMBERK, VELIKI LIPOVEC  Prodaja    Hiša
# 8250                                               ŽVAB  Prodaja    Hiša
# 8251                                             ŽVIRČE  Prodaja    Hiša
#
#              tip  leto  zemljisce  velikost      cena  \
# ...
